# %%
# !find partner
# Out:
# find: ‘partner’: No such file or directory

# %%
# !find .
# Out:
# .
# ./webnlg
# ./webnlg/experiments
# ./webnlg/experiments/qwen_webnlg_main_r8_lr2e-4
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20/tokenizer.json
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20/rng_state.pth
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20/adapter_config.json
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20/optimizer.pt
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20/README.md
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20/training_args.bin
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20/tokenizer_config.json
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20/adapter_model.safetensors
# ./webnlg/experiments/qwen_webnlg_pilot_20_steps/checkpoint-20/chat_template.jinja
# ...
